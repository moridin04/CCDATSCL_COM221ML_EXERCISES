# %% [markdown]
# <a href="https://colab.research.google.com/github/moridin04/CCDATSCL_COM221ML_EXERCISES/blob/main/Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1
#
# In this activity, you will work with the New York City Airbnb Open Data—a popular, messy, and highly realistic dataset used by data analysts and data scientists around the world. The dataset includes thousands of Airbnb listings along with details about hosts, locations, prices, reviews, and more.
#
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8Pmq3Gv7y7z_2Xun-OqMIk43kd5u0TXEatw&s"/>
#
#
# To guide your work, you will follow the 6-Step Data Wrangling Process, a professional workflow used in industry:
#
# - Discovering. Become familiar with the data by exploring its structure and observing patterns.
#
# - Structuring. Fix issues related to format, column types, indices, and duplicated records.
#
# - Cleaning. Handle missing values, outliers, and inconsistencies so the dataset becomes trustworthy.
#
# - Enriching. Add new features, aggregate information, and enhance the dataset for deeper insights.
#
# - Validating. Apply rule-based checks to ensure the data meets quality standards.
#
# - Publishing. Export and prepare the cleaned dataset for downstream analysis or reporting.
# Throughout this exercise, you will answer questions and fill in code cells based on these six steps. You will mimic what professional data scientists do when preparing data for business intelligence dashboards, machine learning models, or exploratory analysis.

# %%
import kagglehub
import os
import pandas as pd
import numpy as np

# Download latest version
path = kagglehub.dataset_download("dgomonov/new-york-city-airbnb-open-data")

print("Path to dataset files:", path)

if os.path.isdir(path):
  print(True)

contents = os.listdir(path)
contents

mydataset = path + "/" + contents[0]
mydataset


df = pd.read_csv(mydataset)
# Out:
# Using Colab cache for faster access to the 'new-york-city-airbnb-open-data' dataset.
# Path to dataset files: /kaggle/input/new-york-city-airbnb-open-data
# True

# %% [markdown]
# ## A. Discovering

# %% [markdown]
# Display the first 10 rows

# %%
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan              Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan         East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan         Murray Hill  40.74767  -73.97500
# 6        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8    MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
# 9          Ben           Manhattan           Chinatown  40.71344  -73.99037
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
# 5  Entire home/apt    200               3                 74  2019-06-22
# 6     Private room     60              45                 49  2017-10-05
# 7     Private room     79               2                430  2019-06-24
# 8     Private room     79               2                118  2017-07-21
# 9  Entire home/apt    150               1                160  2019-06-09
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0
# 5               0.59                               1               129
# 6               0.40                               1                 0
# 7               3.47                               1               220
# 8               0.99                               1                 0
# 9               1.33                               4               188

# %% [markdown]
# Display the column names:

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# Display the dataframe shape:

# %%
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# Identify the numerical features:

# %%
df.select_dtypes(include=['number']).columns
# Out:
# Index(['id', 'host_id', 'latitude', 'longitude', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %% [markdown]
# Identify the categorical features

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type', 'last_review'],
#       dtype='object')

# %% [markdown]
# What are the top 5 questions this dataset might help answer?

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %% [markdown]
# ## B. Structuring

# %% [markdown]
# Check if the dataset has proper column types

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# Check if the dataset has index issues

# %%
df.index
# Out:
# RangeIndex(start=0, stop=48895, step=1)

# %% [markdown]
# Check if the dataset has duplicated rows

# %%
df.duplicated().sum()
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# Convert columns to correct types (e.g., dates → datetime).

# %%
df['last_review'] = pd.to_datetime(df['last_review'])
df['longitude'] = df['longitude'].astype('int')
df['latitude'] = df['latitude'].astype('int')
df['reviews_per_month'] = df['reviews_per_month'].astype('int')
df['price_per_minimum_night'] = df['price_per_minimum_night'].astype('int')
df['review_rate_per_month'] = df['review_rate_per_month'].astype('int')
df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                   int64
# longitude                                  int64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                          int64
# calculated_host_listings_count             int64
# availability_365                           int64
# price_per_minimum_night                    int64
# review_rate_per_month                      int64
# is_expensive                                bool
# dtype: object

# %% [markdown]
# Identify at least one structural issue and describe how to fix it.

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# price_per_minimum_night           0
# review_rate_per_month             0
# is_expensive                      0
# dtype: int64

# %% [markdown]
# ## C. Cleaning

# %% [markdown]
# Check for missing values

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# price_per_minimum_night           0
# review_rate_per_month             0
# is_expensive                      0
# dtype: int64

# %% [markdown]
# Check for outliers in `minimum_nights`

# %%
df['minimum_nights'].describe()
# Out:
# count    38811.000000
# mean         5.868723
# std         17.390315
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# Check for invalid values (e.g., price ≤ 0)

# %%
df[df['price'] <= 0]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, price_per_minimum_night, review_rate_per_month, is_expensive]
# Index: []

# %% [markdown]
# Apply a missing-value strategy (drop, fill, or flag)

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# price_per_minimum_night           0
# review_rate_per_month             0
# is_expensive                      0
# dtype: int64

# %% [markdown]
# Apply an outlier-handling strategy

# %%
df.drop(df[df['price'] <= 0].index, inplace=True)
df.shape
# Out:
# (38811, 19)

# %% [markdown]
# ## D. Enriching

# %% [markdown]
# Create at least 3 new variables:
# - price_per_minimum_night
# - review_rate_per_month (combine ratings + frequency)
# - is_expensive (boolean flag based on price threshold)

# %%
df['price_per_minimum_night'] = df['price'] / df['minimum_nights']
df['review_rate_per_month'] = df['number_of_reviews'] * df['reviews_per_month']
df['is_expensive'] = df['price'] > 1000
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington        40        -73
# 1     Jennifer           Manhattan       Midtown        40        -73
# 3  LisaRoxanne            Brooklyn  Clinton Hill        40        -73
# 4        Laura           Manhattan   East Harlem        40        -73
# 5        Chris           Manhattan   Murray Hill        40        -73
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
# 5  Entire home/apt    200               3                 74  2019-06-22
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                  0                               6               365
# 1                  0                               2               355
# 3                  4                               1               194
# 4                  0                               1                 0
# 5                  0                               1               129
#
#    price_per_minimum_night  review_rate_per_month  is_expensive
# 0               149.000000                      0         False
# 1               225.000000                      0         False
# 3                89.000000                   1080         False
# 4                 8.000000                      0         False
# 5                66.666667                      0         False

# %% [markdown]
# Create 1 aggregated summary table
#
# (e.g. average price per neighborhood, number of hosts per borough)

# %%
df.groupby('neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx             79.649886
# Brooklyn         121.529823
# Manhattan        180.071596
# Queens            95.783683
# Staten Island     89.964968
# Name: price, dtype: float64

# %% [markdown]
# ## E. Validating

# %% [markdown]
# Create at least 3 validation checks
# - Price must be positive.
# - Host ID should not be null.
# - Minimum nights must be ≥ 1.
# - Generate a validation report:
# - Count of rows violating each rule.
#
# Decide if invalid rows (if any) should be removed or corrected?

# %%
#Host ID shouldn't be null
df['host_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
#Price must be positive
df[df['price'] <= 0]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, price_per_minimum_night, review_rate_per_month, is_expensive]
# Index: []

# %%
#Minimum nights should be >=1
df[df['minimum_nights'] <= 0]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, price_per_minimum_night, review_rate_per_month, is_expensive]
# Index: []

# %% [markdown]
# ## F. Publishing

# %% [markdown]
# Select final columns for publication.

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'price_per_minimum_night', 'review_rate_per_month',
#        'is_expensive'],
#       dtype='object')

# %%
df = df[['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
       'neighbourhood', 'latitude', 'longitude', 'room_type', 'last_review',
       'calculated_host_listings_count',
       'availability_365', 'price_per_minimum_night', 'review_rate_per_month',
       'is_expensive']]
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington        40        -73
# 1     Jennifer           Manhattan       Midtown        40        -73
# 3  LisaRoxanne            Brooklyn  Clinton Hill        40        -73
# 4        Laura           Manhattan   East Harlem        40        -73
# 5        Chris           Manhattan   Murray Hill        40        -73
#
#          room_type last_review  calculated_host_listings_count  \
# 0     Private room  2018-10-19                               6
# 1  Entire home/apt  2019-05-21                               2
# 3  Entire home/apt  2019-07-05                               1
# 4  Entire home/apt  2018-11-19                               1
# 5  Entire home/apt  2019-06-22                               1
#
#    availability_365  price_per_minimum_night  review_rate_per_month  \
# 0               365               149.000000                      0
# 1               355               225.000000                      0
# 3               194                89.000000                   1080
# 4                 0                 8.000000                      0
# 5               129                66.666667                      0
#
#    is_expensive
# 0         False
# 1         False
# 3         False
# 4         False
# 5         False

# %% [markdown]
# Export cleaned dataset as "cleaned_airbnb.csv"

# %%
df.to_csv('cleaned_airbnb.csv')

# %% [markdown]
# Export summary reports (e.g., validation or aggregations) as CSV.

# %%
df.groupby('neighbourhood_group')['price_per_minimum_night'].mean().to_csv('summary_report.csv')
